# %%
# Step 1. Read molecules and create model
from scripts.ed_parser import read
import scripts.model_core as mp
from scripts import get_project_root

file_2fo_fc = str(get_project_root().parent) + '/mol_data/dsn6/4nre_2fofc.dsn6'
file_fo_fc = str(get_project_root().parent) + '/mol_data/dsn6/4nre_fofc.dsn6'

ed_2fo_fc = read(file_2fo_fc)
ed_fo_fc = read(file_fo_fc)
model = mp.Model(ed_2fo_fc, ed_fo_fc)

# %%
# Step 2. Build ground truth difference signal in 2fo-fc map
from scripts.noise_signal_plot import build_signal
build_signal(model)
# Out:
# threshold_ideal 0.5612030848937098
# 155100

# %%
# Out:
# threshold_ideal 0.5612030848937098
# 155100
